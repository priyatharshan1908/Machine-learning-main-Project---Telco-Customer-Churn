# %% [markdown]
# <a href="https://colab.research.google.com/github/priyatharshan1908/Machine-learning-main-Project---Telco-Customer-Churn/blob/main/Main_Project_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🌐
# 📍

# %% [markdown]
# #**Machine Learning Main project**
# ---
# ##**Name Of This Project : Telco Customer📉Churn**📈

# %% [markdown]
# ![DALL·E 2025-03-11 01.01.39 - A professional banner image with the text 'Telco Customer Churn Prediction'. The image includes visuals of a telecom tower, a mobile network signal, a.webp](data:image/webp;base64,...)

# %% [markdown]
# * Github link of this Thdataset🌐: https://github.com/priyatharshan1908/Machine-Learning-Dataset--Telco-Customer-Churn
# * Github link of this project:

# %% [markdown]
# # 🔵**Introduction of the project**
# ---
# ↪ *The Telco Customer Churn dataset tracks customer details like contract type, monthly charges, and tenure to predict who might leave. Analyzing it helps businesses understand churn patterns and improve retention.*

# %% [markdown]
# #🔵**Summary of this dataset**
# ___
#  #### ↪ *This dataset contains 7,043 customer records with 21 features related to customer details, services, and billing. The key goal is to predict customer churn (whether a customer will leave or stay).*
#
#  📍 Main Features: Customer demographics, service usage, contract type, and billing details.
#
# 📍 Target Variable: Churn (Yes/No).
#
# 📍 Missing Data: 1,815 values (needs cleaning).
#
# 📍 No Duplicates.

# %% [markdown]
# #🔵**Problem Statement**
# ___
#  ↪ *The Telco Customer Churn dataset tracks customer details like contract type,
# monthly charges, and tenure to predict who might leave. Analyzing it helps businesses understand churn patterns and improve retention.*

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Upload a dataset & using pandas to read a 'CSV' file
data = pd.read_csv("Telco_Customer_Churn.csv")
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No     1.0
# 1     5575-GNVDE    Male              0      No         No    34.0
# 2     3668-QPYBK    Male              0      No         No     2.0
# 3     7795-CFOCW    Male              0      No         No    45.0
# 4     9237-HQITU  Female              0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes    24.0
# 7039  2234-XADUH  Female              0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female              0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male              1     Yes         No     4.0
# 7042  3186-AJIEK    Male              0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# Using a function "shape"
data.shape
# Out:
# (7043, 21)

# %%
# Using a function "describe"
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  6841.000000     6595.000000
# mean        0.162147    32.390440       64.961183
# std         0.368612    24.562202       30.062419
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.900000
# 50%         0.000000    29.000000       70.450000
# 75%         0.000000    55.000000       90.000000
# max         1.000000    72.000000      118.750000

# %%
# Information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            6841 non-null   float64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   6837 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       6923 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          6872 non-null   object
# ...

# %%
# In this Function shows a types of coloumns
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure              float64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# This function shows a duplicated values in coloumns & using sum
data.duplicated().sum()
# Out:
# 0

# %%
# If data had a null values it will shows & using sum
data.isnull().sum()
# Out:
# customerID            0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure              202
# PhoneService          0
# MultipleLines         0
# InternetService     206
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport         120
# StreamingTV           0
# StreamingMovies       0
# Contract            171
# PaperlessBilling      0
# PaymentMethod       288
# MonthlyCharges      448
# TotalCharges        380
# Churn                 0
# dtype: int64

# %%
# Copying dataset to "data1"
data1=data.copy()

# %%
# It shows a column of copying dataset "dataset1"
data1.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# This is a Head of dataset- data1
# Using (5) to shows 1 to 5 rows
data1.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No     1.0           No
# 1  5575-GNVDE    Male              0      No         No    34.0          Yes
# 2  3668-QPYBK    Male              0      No         No     2.0          Yes
# 3  7795-CFOCW    Male              0      No         No    45.0           No
# 4  9237-HQITU  Female              0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Impute a null values using (mode) or (median)
# If columns are numerical using "mean"
data1["tenure"].fillna(data1["tenure"].mean,inplace=True)
data1["MonthlyCharges"].fillna(data1['MonthlyCharges'].mean,inplace=True)
data1["TotalCharges"].fillna(data1["TotalCharges"].mean,inplace = True)
# If colomns are categorical using "mode"
data1["InternetService"].fillna(data1["InternetService"].mode()[0],inplace=True)
data1["TechSupport"].fillna(data1["TechSupport"].mode()[0],inplace = True)
data1["Contract"].fillna(data1["Contract"].mode()[0],inplace=True)
data1["PaymentMethod"].fillna(data1["PaymentMethod"].mode()[0],inplace =True)

# %%
# After that cleaning using isnull function
data1.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64
